# %%
import numpy as np
cycle_days=100000./24./3600.
print(cycle_days)
shortdepth=1500.
longdepth=1600.
holddepth = 1500.
speed=0.12
surftime_min=30.
extra_time=2*3600.
TCR = cycle_days*24*3600.
# time hold long
THL = TCR-(longdepth+(longdepth-holddepth))/speed-surftime_min*60+extra_time
TCHLB = shortdepth/speed
TCHLE = THL-holddepth/speed-1000.
TDPHL = THL +(longdepth-holddepth)/speed + 3600.
TDPHS = shortdepth/speed+1800.

print('TimeCycleHoldLongBeg = %d' % TCHLB)
print('TimeCycleHoldLongEnd = %d'% TCHLE);
print('TimeCycleRep = %d'% TCR);
print('TimeDescentProfHoldLong = %d' % TDPHL);
print('TimeDescentProfHoldShort = %d'%TDPHS);
print('TimeHoldLong = %d'%THL)
# Out:
# 1.15740740741
# TimeCycleHoldLongBeg = 12500
# TimeCycleHoldLongEnd = 77733
# TimeCycleRep = 100000
# TimeDescentProfHoldLong = 95666
# TimeDescentProfHoldShort = 14300
# TimeHoldLong = 91233

# %%
cycle = 10*24*3600 #s this is what we'd like (we won't get it)
print cycle
surftime = 30.*60.
holddepth = 1583. # get this from a simulation.  It is set by `PistonFollowDefault`
PrBotHoldLong = 1610.
speed = 0.12

# how deep can we go to get the inertial pair?
dt = 14.35*3600./2.
print dt
dt = dt-surftime # subtract the transmit
PrBotHoldShort = dt*speed/2.
print('PrBotHoldLong: %1.0f dbar'% np.round(PrBotHoldLong))
print('PrBotHoldShort: %1.0f dbar'% np.round(PrBotHoldShort))

# get TimeHoldLong
TimeHoldLong = cycle-np.abs(PrBotHoldLong-holddepth)/speed \
  -PrBotHoldLong/speed \
            -surftime
print(PrBotHoldLong/speed)
print('TimeHoldLong: %1.0f'%np.round(TimeHoldLong))

# get the maximum TimeCycleHoldLongBeg
TCHLB = 2.*PrBotHoldShort/speed
print('TimeCycleHoldLongBeg should be less than %d'%round(TCHLB))
print('TimeDescentProfHoldLong should be greater than %d'%round(cycle))
# Out:
# 864000
# 25830.0
# PrBotHoldLong: 1610 dbar
# PrBotHoldShort: 1442 dbar
# 13416.6666667
# TimeHoldLong: 848558
# TimeCycleHoldLongBeg should be less than 24030
# TimeDescentProfHoldLong should be greater than 864000

# %% [markdown]
# ## Compare two files:

# %%
def getParams(ifile):
    mp=dict()
    ifp = open(ifile, mode='rt')
    
    for line in ifp:
        if line.find('=') > 0:
            if '#' in line:
                i = line.find('#')
                line = line[0:i]
            line = line.strip()
            if line.find('=') > 0:
                tok = line.split('=')
                if len(tok)!=2:
                    sys.exit()

                varnam=tok[0].strip()
                varval=tok[1].strip()
                mp[varnam]=varval
    return mp

# %%
mpjmk=getParams('EMAPEXLabSea15/MissionParams/jmklabseaparams.txt')
mprf=getParams('EMAPEXLabSea15/MissionParams/Argo_labsea3_mission.txt')
#print mpjmk

print 'THESE ARE DIFFERENT  JMK vs RF'
for key,value in sorted(mpjmk.items()):
    if key in mprf.keys():
        if value!=mprf[key]:
            print ('%30s'%key),'=',value,'  vs  ',mprf[key]
    else:
#        print key
        pass
print 'NOT IN JMK'
for key,value in sorted(mprf.items()):
    if not(key in mpjmk.keys()):
        print key,value
print 'NOT IN RF'
for key,value in sorted(mpjmk.items()):
    if not(key in mprf.keys()):
        print key,value
print 'THESE ARE THE SAME!'
for key,value in sorted(mpjmk.items()):
    if key in mprf.keys():
        if value==mprf[key]:
            print ('%30s'%key),'=',value,'  vs  ',mprf[key]
    else:
#        print key
        pass
# Out:
# THESE ARE DIFFERENT  JMK vs RF
#               EmaProcessNslide = 40   vs   25
#                EmaProcessNvals = 40   vs   50
#                     FloatAlpha = -3.673e-06   vs   -0.000003673
#                      FloatBeta = 3.2e-05   vs   0.000032
#                     OptodeMode = 0   vs   1
#             PistonParkPosition = 42   vs   63
#          PistonStoragePosition = 42   vs   16
#           PressureMaxRecordRaw = 500   vs   100
#                   PressurePark = 1000   vs   1500
#                   RawEfSaveRep = 30   vs   10
#           SalinityBallastPoint = 34.7   vs   34.6
#        TemperatureBallastPoint = 0.4   vs   1.8
#           TimeCycleHoldLongEnd = 167733   vs   160000
# NOT IN JMK
# 2DurationFastProfiling 43200
# NOT IN RF
# ConsoleBaudRate 4800
# CtdPmin 5
# CtdSampleDelPr1 2
# CtdSampleDelPr2 10
# CtdSampleDelPr3 20
# CtdSampleDelPr4 50
# CtdSampleN1 1100
# CtdSampleN2 20
# CtdSampleN3 20
# CtdSampleN4 20
# CtdSamplePrFirst 2
# CtdType 4
# DateCycleStarted 2014/11/03 19:49:42
# DateNextLevel2 2014/11/04 08:49:42
# DatePreludeEnded 2013/09/16 08:18:47
# DurationFastProfiling 0
# FloatId 6478
# FloatMass 27750
# KermitPacketLength 1000
# KermitWindowSlots 3
# LoginName xxxxxxxxxxxxxxxxxxxx
# ModemBaudRate 19200
# ModemType I
# Password xxxxxxxxxxxxxxxxxxxx
# PhoneNumbers R0088160000533,0012062213248,0012065439844,0012065439845
# PvtDateRef 1970/01/01 00:00:00
# PvtPistonDiffMax 10
# PvtTimeAllowStartDown 360
# PvtTimeAllowStartUp 240
# PvtTimeRep 0
# PvtWaitAtSurface 0
# Pvt_alpha 12
# Pvt_b0 10
# Pvt_pmin_offset 3
# SimulationDpdtCoef 0.02
# SimulationPrBot 3000
# TM_betaMax 0.0351
# TM_betaMin 0.0349
# TM_betaNominal 0.035
# TM_fBeg 2
# TM_fft_navg 2
# TM_fft_size 2048
# TM_freqType 1
# TM_gBlkNumRequested 2
# TM_gProfNumRequested 0
# TM_profnum_offset 0
# TM_pstart 0
# TM_snf_filterType 9
# TM_snf_freqType 0
# TM_snf_t1FreqLvl_N 3
# TM_snf_t1Freq_0 0.001
# TM_snf_t1Freq_1 2
# TM_snf_t1Freq_2 120
# TM_snf_t1Freq_3 0
# TM_snf_t1Freq_4 0
# TM_snf_t1Freq_5 0
# TM_snf_t1Freq_6 0
# TM_snf_t1Freq_7 0
# TM_snf_t1Freq_8 0
# TM_snf_t1Freq_9 0
# TM_snf_t1Level_0 2e-11
# TM_snf_t1Level_1 2e-11
# TM_snf_t1Level_2 6e-10
# TM_snf_t1Level_3 0
# TM_snf_t1Level_4 0
# TM_snf_t1Level_5 0
# TM_snf_t1Level_6 0
# TM_snf_t1Level_7 0
# TM_snf_t1Level_8 0
# TM_snf_t1Level_9 0
# TM_snf_t2FreqLvl_N 3
# TM_snf_t2Freq_0 0.001
# TM_snf_t2Freq_1 2
# TM_snf_t2Freq_2 120
# TM_snf_t2Freq_3 0
# TM_snf_t2Freq_4 0
# TM_snf_t2Freq_5 0
# TM_snf_t2Freq_6 0
# TM_snf_t2Freq_7 0
# TM_snf_t2Freq_8 0
# TM_snf_t2Freq_9 0
# TM_snf_t2Level_0 2e-11
# TM_snf_t2Level_1 2e-11
# TM_snf_t2Level_2 6e-10
# TM_snf_t2Level_3 0
# TM_snf_t2Level_4 0
# TM_snf_t2Level_5 0
# TM_snf_t2Level_6 0
# TM_snf_t2Level_7 0
# TM_snf_t2Level_8 0
# TM_snf_t2Level_9 0
# TM_snf_threshFactor 1
# debuglevel 2
# hpid 320
# logport_baud 4800
# logport_key C
# mlt_vit 2014/11/04 04:24:19
# simulate_hardware 0
# simulate_pressure 0
# vit_vers u
# THESE ARE THE SAME!
#                DateForRecovery = 1970/01/01 00:00:00   vs   1970/01/01 00:00:00
#             DescentCtdScanType = 3   vs   3
#                   EfCoefFactor = 0.25   vs   0.25
#           FirstTwoProfsSpecial = 0   vs   0
#                      FlbbMaxPr = 300   vs   300
#                       FlbbMode = 0   vs   0
#           GpsAlmanacOkAtLaunch = 1   vs   1
#               HeartBeatHolding = 300   vs   300
#                  HeartBeatPark = 3600   vs   3600
#                  HeartBeatProf = 6   vs   6
#                  IdFirstLevel2 = 2   vs   2
#                    IridiumIRep = 0   vs   0
#                    IridiumNRep = 1   vs   1
#                      KermitBps = 100   vs   100
#                      KermitRtt = 10   vs   10
#                  MaxAirBladder = 125   vs   125
#                   ModeHoldLong = 2   vs   2
#                  ModeHoldShort = 0   vs   0
#                NstuckThreshold = 10   vs   10
#                  OkVacuumCount = 96   vs   96
#              OpenAirValveAfter = 1   vs   1
#                    OptodeMaxPr = 2000   vs   2000
#            PistonBuoyancyNudge = 6   vs   6
#              PistonCountsPerCC = 0.8650790   vs   0.8650790
#      PistonDeepProfilePosition = 39   vs   39
#            PistonFollowDefault = 62   vs   62
#            PistonFullExtension = 227   vs   227
#           PistonFullRetraction = 9   vs   9
#       PistonInitAscentHoldLong = 90   vs   90
#      PistonInitAscentHoldShort = 97   vs   97
#         PistonInitAscentLevel1 = 94   vs   94
#         PistonInitAscentLevel2 = 82   vs   82
#          PistonInitDescentProf = 66   vs   66
#     PistonInitDescentProfFirst = 9   vs   9
#     PistonInitialBuoyancyNudge = 22   vs   22
#                 PnpCycleLength = 0   vs   0
#                  PrBotHoldLong = 1650   vs   1650
#                 PrBotHoldShort = 1442   vs   1442
#                    PrBotLevel1 = 1330   vs   1330
#                    PrBotLevel2 = 1270   vs   1270
#                      PrBotYoyo = 0   vs   0
#                  PrTopHoldLong = 0   vs   0
#                 PrTopHoldShort = 0   vs   0
#                      PrTopYoyo = 0   vs   0
#       PreludePressureThreshold = 10   vs   10
#               PreludeRepPeriod = 100   vs   100
#             PressureAnticipate = 3   vs   3
#           PressureBallastPoint = 2000   vs   2000
#                   PressureDeep = 1950   vs   1950
#          PressureFollowDefault = 1600   vs   1600
#              PressureFollowMax = 0   vs   0
#              PressureFollowMin = 0   vs   0
#            PressureNearSurface = 3   vs   3
#         RawEfSendFlagProfiling = 1   vs   1
#          RawEfSendFlagRecovery = 0   vs   0
#                 RawSvBytesStop = 6000000   vs   6000000
#            RecoveryIRepConnect = 0   vs   0
#            RecoveryNRepConnect = 1   vs   1
#              RecoveryRepPeriod = 900   vs   900
#            SendCurrentGpsFirst = 0   vs   0
#                    SendOnlyGps = 0   vs   0
#               SigmaThetaFollow = 0   vs   0
#           TimeCycleHoldLongBeg = 22000   vs   22000
#                   TimeCycleRep = 78000   vs   78000
#               TimeCycleYoyoBeg = 0   vs   0
#               TimeCycleYoyoEnd = 0   vs   0
#                TimeDescentDeep = 20000   vs   20000
#                TimeDescentPark = 40000   vs   40000
#                TimeDescentProf = 95000   vs   95000
#        TimeDescentProfHoldLong = 100000   vs   100000
#       TimeDescentProfHoldShort = 14300   vs   14300
#                       TimeDown = 0   vs   0
#                TimeForRecovery = 0   vs   0
#                 TimeGpsGrabRep = 15   vs   15
#               TimeGpsUpdateRep = 1209600   vs   1209600
#                   TimeHoldLong = 83617   vs   83617
#                  TimeHoldShort = 0   vs   0
#                  TimeLevel2Rep = 0   vs   0
#                   TimeOutNudge = 8   vs   8
#              TimePistonIfNoObs = 0   vs   0
#                    TimePrelude = 0   vs   0
#                         TimeUp = 32000   vs   32000
#                TimeYoyoOnceBeg = 0   vs   0
#                TimeYoyoOnceEnd = 0   vs   0
#                      TmoAscent = 30000   vs   30000
#                     TmoConnect = 300   vs   300
#                    TmoGpsAfter = 180   vs   180
#                    TmoGpsShort = 300   vs   300
#                   TmoGpsUpdate = 1800   vs   1800
#                   TmoTelemetry = 600   vs   600
#            TmoXfrFastProfiling = 1800   vs   1800
#                      TmoXfrMin = 300   vs   300
#                TmoXfrProfiling = 1200   vs   1200
#                 TmoXfrRecovery = 300   vs   300
#                           Vmin = 0.12   vs   0.12
#                VstuckThreshold = 0.01   vs   0.01
#                    use_iPiston = 1   vs   1

# %%
mpd=_asdict(mp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-2cfe1900aa80> in <module>()
# ----> 1 mpd=_asdict(mp)
#
# NameError: name '_asdict' is not defined

# %% [markdown]
# ## Prettify files

# %%
def prettify(ifile,ofile):
    mp=dict()
    ifp = open(ifile, mode='rt')
    ofp = open(ofile, mode='wt')
    
    for line in ifp:
        if line.find('=') > 0:
            tok = line.split('=',1)
            line.split()
            if len(tok)!=2:
                sys.exit()

            varnam=tok[0].strip()
            varval=tok[1].strip()
            st = varnam
            stlen = len(st)
            for i in range(27-stlen):
                st = st+' '
            mp[varnam]=st+'= '+tok[1][:-1]
    
    for key,value in sorted(mp.items()):
        ofp.write(value+'\n')
    ofp.close()
    ifp.close()

# %%
mp=prettify('EMAPEXLabSea15/MissionParams/Argo_labsea3_mission.txt','EMAPEXLabSea15/MissionParams/LabseaMission001.txt',)
